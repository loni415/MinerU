# %% [markdown]
# <a href="https://colab.research.google.com/github/loni415/MinerU/blob/master/mineru_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # minerU install and use demo

# %% [markdown]
# ## 1.Install

# %% [markdown]
# ### Install via pip or uv

# %%
# !pip install --upgrade pip
# !pip install "mineru[core]>=2.0.0"
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.11/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.1.1-py3-none-any.whl.metadata (3.6 kB)
# Downloading pip-25.1.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 33.9 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-25.1.1
# Collecting mineru>=2.0.0 (from mineru[core]>=2.0.0)
#   Downloading mineru-2.0.0-py3-none-any.whl.metadata (63 kB)
# Collecting boto3>=1.28.43 (from mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading boto3-1.38.36-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.11/dist-packages (from mineru>=2.0.0->mineru[core]>=2.0.0) (8.2.1)
# Collecting loguru>=0.7.2 (from mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.11/dist-packages (from mineru>=2.0.0->mineru[core]>=2.0.0) (2.0.2)
# Collecting pdfminer.six==20250506 (from mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading pdfminer_six-20250506-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: tqdm>=4.67.1 in /usr/local/lib/python3.11/dist-packages (from mineru>=2.0.0->mineru[core]>=2.0.0) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from mineru>=2.0.0->mineru[core]>=2.0.0) (2.32.3)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/dist-packages (from mineru>=2.0.0->mineru[core]>=2.0.0) (0.28.1)
# Requirement already satisfied: pillow>=11.0.0 in /usr/local/lib/python3.11/dist-packages (from mineru>=2.0.0->mineru[core]>=2.0.0) (11.2.1)
# Collecting pypdfium2>=4.30.0 (from mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
# Collecting pypdf>=5.6.0 (from mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading pypdf-5.6.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting reportlab (from mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading reportlab-4.4.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting pdftext>=0.6.2 (from mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading pdftext-0.6.3-py3-none-any.whl.metadata (8.5 kB)
# Collecting modelscope>=1.26.0 (from mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading modelscope-1.27.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: huggingface-hub>=0.32.4 in /usr/local/lib/python3.11/dist-packages (from mineru>=2.0.0->mineru[core]>=2.0.0) (0.32.4)
# Collecting json-repair>=0.46.2 (from mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading json_repair-0.46.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six==20250506->mineru>=2.0.0->mineru[core]>=2.0.0) (3.4.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six==20250506->mineru>=2.0.0->mineru[core]>=2.0.0) (43.0.3)
# Collecting botocore<1.39.0,>=1.38.36 (from boto3>=1.28.43->mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading botocore-1.38.36-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.28.43->mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.14.0,>=0.13.0 (from boto3>=1.28.43->mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading s3transfer-0.13.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore<1.39.0,>=1.38.36->boto3>=1.28.43->mineru>=2.0.0->mineru[core]>=2.0.0) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore<1.39.0,>=1.38.36->boto3>=1.28.43->mineru>=2.0.0->mineru[core]>=2.0.0) (2.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.39.0,>=1.38.36->boto3>=1.28.43->mineru>=2.0.0->mineru[core]>=2.0.0) (1.17.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=36.0.0->pdfminer.six==20250506->mineru>=2.0.0->mineru[core]>=2.0.0) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20250506->mineru>=2.0.0->mineru[core]>=2.0.0) (2.22)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.32.4->mineru>=2.0.0->mineru[core]>=2.0.0) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.32.4->mineru>=2.0.0->mineru[core]>=2.0.0) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.32.4->mineru>=2.0.0->mineru[core]>=2.0.0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.32.4->mineru>=2.0.0->mineru[core]>=2.0.0) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.32.4->mineru>=2.0.0->mineru[core]>=2.0.0) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.32.4->mineru>=2.0.0->mineru[core]>=2.0.0) (1.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from modelscope>=1.26.0->mineru>=2.0.0->mineru[core]>=2.0.0) (75.2.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.1 in /usr/local/lib/python3.11/dist-packages (from pdftext>=0.6.2->mineru>=2.0.0->mineru[core]>=2.0.0) (2.11.5)
# Collecting pydantic-settings<3.0.0,>=2.2.1 (from pdftext>=0.6.2->mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading pydantic_settings-2.9.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting pypdfium2>=4.30.0 (from mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.1->pdftext>=0.6.2->mineru>=2.0.0->mineru[core]>=2.0.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.1->pdftext>=0.6.2->mineru>=2.0.0->mineru[core]>=2.0.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.1->pdftext>=0.6.2->mineru>=2.0.0->mineru[core]>=2.0.0) (0.4.1)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.2.1->pdftext>=0.6.2->mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->mineru>=2.0.0->mineru[core]>=2.0.0) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->mineru>=2.0.0->mineru[core]>=2.0.0) (2025.4.26)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx->mineru>=2.0.0->mineru[core]>=2.0.0) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx->mineru>=2.0.0->mineru[core]>=2.0.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx->mineru>=2.0.0->mineru[core]>=2.0.0) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx->mineru>=2.0.0->mineru[core]>=2.0.0) (1.3.1)
# Requirement already satisfied: matplotlib<4,>=3.10 in /usr/local/lib/python3.11/dist-packages (from mineru>=2.0.0->mineru[core]>=2.0.0) (3.10.0)
# Collecting ultralytics<9,>=8.3.48 (from mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading ultralytics-8.3.154-py3-none-any.whl.metadata (37 kB)
# Collecting doclayout_yolo==0.0.4 (from mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading doclayout_yolo-0.0.4-py3-none-any.whl.metadata (13 kB)
# Collecting dill<1,>=0.3.8 (from mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting rapid_table<2.0.0,>=1.0.5 (from mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading rapid_table-1.0.5-py3-none-any.whl.metadata (1.1 kB)
# Collecting ftfy<7,>=6.3.1 (from mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: openai<2,>=1.70.0 in /usr/local/lib/python3.11/dist-packages (from mineru>=2.0.0->mineru[core]>=2.0.0) (1.84.0)
# Requirement already satisfied: shapely<3,>=2.0.7 in /usr/local/lib/python3.11/dist-packages (from mineru>=2.0.0->mineru[core]>=2.0.0) (2.1.1)
# Collecting pyclipper<2,>=1.3.0 (from mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading pyclipper-1.3.0.post6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: omegaconf<3,>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from mineru>=2.0.0->mineru[core]>=2.0.0) (2.3.0)
# Requirement already satisfied: torch!=2.5.0,!=2.5.1,<3,>=2.2.2 in /usr/local/lib/python3.11/dist-packages (from mineru>=2.0.0->mineru[core]>=2.0.0) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from mineru>=2.0.0->mineru[core]>=2.0.0) (0.21.0+cu124)
# Requirement already satisfied: transformers!=4.51.0,<5.0.0,>=4.49.0 in /usr/local/lib/python3.11/dist-packages (from mineru>=2.0.0->mineru[core]>=2.0.0) (4.52.4)
# Collecting fast-langdetect<0.3.0,>=0.2.3 (from mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading fast_langdetect-0.2.5-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from doclayout_yolo==0.0.4->mineru>=2.0.0->mineru[core]>=2.0.0) (4.11.0.86)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from doclayout_yolo==0.0.4->mineru>=2.0.0->mineru[core]>=2.0.0) (1.15.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from doclayout_yolo==0.0.4->mineru>=2.0.0->mineru[core]>=2.0.0) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from doclayout_yolo==0.0.4->mineru>=2.0.0->mineru[core]>=2.0.0) (9.0.0)
# Collecting thop>=0.1.1 (from doclayout_yolo==0.0.4->mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from doclayout_yolo==0.0.4->mineru>=2.0.0->mineru[core]>=2.0.0) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from doclayout_yolo==0.0.4->mineru>=2.0.0->mineru[core]>=2.0.0) (0.13.2)
# Requirement already satisfied: albumentations>=1.4.11 in /usr/local/lib/python3.11/dist-packages (from doclayout_yolo==0.0.4->mineru>=2.0.0->mineru[core]>=2.0.0) (2.0.8)
# Collecting robust-downloader>=0.0.2 (from fast-langdetect<0.3.0,>=0.2.3->mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading robust_downloader-0.0.2-py3-none-any.whl.metadata (4.1 kB)
# Collecting fasttext-predict>=0.9.2.4 (from fast-langdetect<0.3.0,>=0.2.3->mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading fasttext_predict-0.9.2.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy<7,>=6.3.1->mineru>=2.0.0->mineru[core]>=2.0.0) (0.2.13)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4,>=3.10->mineru>=2.0.0->mineru[core]>=2.0.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4,>=3.10->mineru>=2.0.0->mineru[core]>=2.0.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4,>=3.10->mineru>=2.0.0->mineru[core]>=2.0.0) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4,>=3.10->mineru>=2.0.0->mineru[core]>=2.0.0) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4,>=3.10->mineru>=2.0.0->mineru[core]>=2.0.0) (3.2.3)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from omegaconf<3,>=2.3.0->mineru>=2.0.0->mineru[core]>=2.0.0) (4.9.3)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai<2,>=1.70.0->mineru>=2.0.0->mineru[core]>=2.0.0) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai<2,>=1.70.0->mineru>=2.0.0->mineru[core]>=2.0.0) (0.10.0)
# Collecting onnxruntime>1.17.0 (from rapid_table<2.0.0,>=1.0.5->mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading onnxruntime-1.22.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting colorlog (from rapid_table<2.0.0,>=1.0.5->mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch!=2.5.0,!=2.5.1,<3,>=2.2.2->mineru>=2.0.0->mineru[core]>=2.0.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch!=2.5.0,!=2.5.1,<3,>=2.2.2->mineru>=2.0.0->mineru[core]>=2.0.0) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch!=2.5.0,!=2.5.1,<3,>=2.2.2->mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch!=2.5.0,!=2.5.1,<3,>=2.2.2->mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch!=2.5.0,!=2.5.1,<3,>=2.2.2->mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch!=2.5.0,!=2.5.1,<3,>=2.2.2->mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch!=2.5.0,!=2.5.1,<3,>=2.2.2->mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch!=2.5.0,!=2.5.1,<3,>=2.2.2->mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch!=2.5.0,!=2.5.1,<3,>=2.2.2->mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch!=2.5.0,!=2.5.1,<3,>=2.2.2->mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch!=2.5.0,!=2.5.1,<3,>=2.2.2->mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch!=2.5.0,!=2.5.1,<3,>=2.2.2->mineru>=2.0.0->mineru[core]>=2.0.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch!=2.5.0,!=2.5.1,<3,>=2.2.2->mineru>=2.0.0->mineru[core]>=2.0.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch!=2.5.0,!=2.5.1,<3,>=2.2.2->mineru>=2.0.0->mineru[core]>=2.0.0) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch!=2.5.0,!=2.5.1,<3,>=2.2.2->mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch!=2.5.0,!=2.5.1,<3,>=2.2.2->mineru>=2.0.0->mineru[core]>=2.0.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch!=2.5.0,!=2.5.1,<3,>=2.2.2->mineru>=2.0.0->mineru[core]>=2.0.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch!=2.5.0,!=2.5.1,<3,>=2.2.2->mineru>=2.0.0->mineru[core]>=2.0.0) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers!=4.51.0,<5.0.0,>=4.49.0->mineru>=2.0.0->mineru[core]>=2.0.0) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers!=4.51.0,<5.0.0,>=4.49.0->mineru>=2.0.0->mineru[core]>=2.0.0) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers!=4.51.0,<5.0.0,>=4.49.0->mineru>=2.0.0->mineru[core]>=2.0.0) (0.5.3)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics<9,>=8.3.48->mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.11/dist-packages (from albumentations>=1.4.11->doclayout_yolo==0.0.4->mineru>=2.0.0->mineru[core]>=2.0.0) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.11/dist-packages (from albumentations>=1.4.11->doclayout_yolo==0.0.4->mineru>=2.0.0->mineru[core]>=2.0.0) (4.11.0.86)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.24->albumentations>=1.4.11->doclayout_yolo==0.0.4->mineru>=2.0.0->mineru[core]>=2.0.0) (3.12.5)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.24->albumentations>=1.4.11->doclayout_yolo==0.0.4->mineru>=2.0.0->mineru[core]>=2.0.0) (6.4.7)
# Collecting coloredlogs (from onnxruntime>1.17.0->rapid_table<2.0.0,>=1.0.5->mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime>1.17.0->rapid_table<2.0.0,>=1.0.5->mineru>=2.0.0->mineru[core]>=2.0.0) (25.2.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime>1.17.0->rapid_table<2.0.0,>=1.0.5->mineru>=2.0.0->mineru[core]>=2.0.0) (5.29.5)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->doclayout_yolo==0.0.4->mineru>=2.0.0->mineru[core]>=2.0.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->doclayout_yolo==0.0.4->mineru>=2.0.0->mineru[core]>=2.0.0) (2025.2)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>1.17.0->rapid_table<2.0.0,>=1.0.5->mineru>=2.0.0->mineru[core]>=2.0.0)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch!=2.5.0,!=2.5.1,<3,>=2.2.2->mineru>=2.0.0->mineru[core]>=2.0.0) (3.0.2)
# Requirement already satisfied: accelerate>=1.5.1 in /usr/local/lib/python3.11/dist-packages (from mineru>=2.0.0->mineru[core]>=2.0.0) (1.7.0)
# Requirement already satisfied: chardet in /usr/local/lib/python3.11/dist-packages (from reportlab->mineru>=2.0.0->mineru[core]>=2.0.0) (5.2.0)
# Downloading mineru-2.0.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 45.4 MB/s eta 0:00:00
# Downloading pdfminer_six-20250506-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 124.0 MB/s eta 0:00:00
# Downloading boto3-1.38.36-py3-none-any.whl (139 kB)
# Downloading botocore-1.38.36-py3-none-any.whl (13.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 180.6 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.13.0-py3-none-any.whl (85 kB)
# Downloading json_repair-0.46.2-py3-none-any.whl (22 kB)
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
# Downloading modelscope-1.27.0-py3-none-any.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 97.8 MB/s eta 0:00:00
# Downloading pdftext-0.6.3-py3-none-any.whl (23 kB)
# Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 116.6 MB/s eta 0:00:00
# Downloading pydantic_settings-2.9.1-py3-none-any.whl (44 kB)
# Downloading pypdf-5.6.0-py3-none-any.whl (304 kB)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading doclayout_yolo-0.0.4-py3-none-any.whl (711 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 711.3/711.3 kB 35.6 MB/s eta 0:00:00
# Downloading dill-0.4.0-py3-none-any.whl (119 kB)
# Downloading fast_langdetect-0.2.5-py3-none-any.whl (786 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 786.6/786.6 kB 40.8 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
# Downloading pyclipper-1.3.0.post6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (969 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 969.6/969.6 kB 50.0 MB/s eta 0:00:00
# Downloading rapid_table-1.0.5-py3-none-any.whl (33 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 28.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 107.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 66.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 35.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 72.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 56.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 65.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 70.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 143.3 MB/s eta 0:00:00
# Downloading ultralytics-8.3.154-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 50.2 MB/s eta 0:00:00
# Downloading fasttext_predict-0.9.2.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (298 kB)
# Downloading onnxruntime-1.22.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 113.5 MB/s eta 0:00:00
# Downloading robust_downloader-0.0.2-py3-none-any.whl (15 kB)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading reportlab-4.4.1-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 38.3 MB/s eta 0:00:00
# Installing collected packages: pyclipper, fasttext-predict, reportlab, python-dotenv, pypdfium2, pypdf, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, loguru, json-repair, jmespath, humanfriendly, ftfy, dill, colorlog, robust-downloader, nvidia-cusparse-cu12, nvidia-cudnn-cu12, modelscope, coloredlogs, botocore, s3transfer, pydantic-settings, pdfminer.six, onnxruntime, nvidia-cusolver-cu12, fast-langdetect, rapid_table, pdftext, boto3, ultralytics-thop, thop, mineru, ultralytics, doclayout_yolo
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.7
#     Uninstalling dill-0.3.7:
#       Successfully uninstalled dill-0.3.7
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40/40 [doclayout_yolo]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 2.14.4 requires dill<0.3.8,>=0.3.0, but you have dill 0.4.0 which is incompatible.
# Successfully installed boto3-1.38.36 botocore-1.38.36 coloredlogs-15.0.1 colorlog-6.9.0 dill-0.4.0 doclayout_yolo-0.0.4 fast-langdetect-0.2.5 fasttext-predict-0.9.2.4 ftfy-6.3.1 humanfriendly-10.0 jmespath-1.0.1 json-repair-0.46.2 loguru-0.7.3 mineru-2.0.0 modelscope-1.27.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 onnxruntime-1.22.0 pdfminer.six-20250506 pdftext-0.6.3 pyclipper-1.3.0.post6 pydantic-settings-2.9.1 pypdf-5.6.0 pypdfium2-4.30.0 python-dotenv-1.1.0 rapid_table-1.0.5 reportlab-4.4.1 robust-downloader-0.0.2 s3transfer-0.13.0 thop-0.1.1.post2209072238 ultralytics-8.3.154 ultralytics-thop-2.0.14

# %% [markdown]
# ### Check verison

# %%
# !mineru -v
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749893599.334293    1417 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749893599.419330    1417 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-14 09:33:25.757 | WARNING  | mineru.backend.vlm.predictor:<module>:35 - sglang is not installed. If you are not using sglang, you can ignore this warning.
# mineru, version 2.0.0

# %% [markdown]
# ## 2.Usage

# %% [markdown]
# ### 2.1Command line

# %% [markdown]
# #### **Download PDF Demo**

# %%
# !wget https://github.com/opendatalab/MinerU/raw/master/demo/pdfs/demo1.pdf && wget https://github.com/opendatalab/MinerU/raw/master/demo/pdfs/demo2.pdf
# Out:
# --2025-06-13 14:29:33--  https://github.com/opendatalab/MinerU/raw/master/demo/pdfs/demo1.pdf
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/opendatalab/MinerU/master/demo/pdfs/demo1.pdf [following]
# --2025-06-13 14:29:33--  https://raw.githubusercontent.com/opendatalab/MinerU/master/demo/pdfs/demo1.pdf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 336919 (329K) [application/octet-stream]
# Saving to: ‘demo1.pdf’
#
# demo1.pdf           100%[===================>] 329.02K  --.-KB/s    in 0.03s
#
# 2025-06-13 14:29:33 (10.9 MB/s) - ‘demo1.pdf’ saved [336919/336919]
#
# --2025-06-13 14:29:33--  https://github.com/opendatalab/MinerU/raw/master/demo/pdfs/demo2.pdf
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/opendatalab/MinerU/master/demo/pdfs/demo2.pdf [following]
# --2025-06-13 14:29:34--  https://raw.githubusercontent.com/opendatalab/MinerU/master/demo/pdfs/demo2.pdf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1808096 (1.7M) [application/octet-stream]
# Saving to: ‘demo2.pdf’
#
# demo2.pdf           100%[===================>]   1.72M  --.-KB/s    in 0.04s
#
# 2025-06-13 14:29:34 (42.4 MB/s) - ‘demo2.pdf’ saved [1808096/1808096]

# %% [markdown]
# #### **Convert Single PDF**

# %%
# !mineru -p demo1.pdf -o ./output
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749825017.529436    2031 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749825017.535284    2031 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-13 14:30:20.846 | WARNING  | mineru.backend.vlm.predictor:<module>:35 - sglang is not installed. If you are not using sglang, you can ignore this warning.
# 2025-06-13 14:30:24.729 | INFO     | mineru.backend.pipeline.pipeline_analyze:doc_analyze:128 - Batch 1/1: 13 pages/13 pages
# 2025-06-13 14:30:24.732 | INFO     | mineru.backend.pipeline.pipeline_analyze:batch_image_analyze:191 - gpu_memory: 15 GB, batch_ratio: 8
# 2025-06-13 14:30:24.732 | INFO     | mineru.backend.pipeline.model_init:__init__:137 - DocAnalysis init, this may take some times......
# Fetching 1 files:   0% 0/1 [00:00<?, ?it/s]
# yolo_v8_ft.pt:   0% 0.00/350M [00:00<?, ?B/s]
# yolo_v8_ft.pt:   6% 21.0M/350M [00:00<00:02, 159MB/s]
# yolo_v8_ft.pt:  15% 52.4M/350M [00:00<00:01, 220MB/s]
# yolo_v8_ft.pt:  27% 94.4M/350M [00:00<00:00, 267MB/s]
# yolo_v8_ft.pt:  36% 126M/350M [00:00<00:00, 278MB/s]
# yolo_v8_ft.pt:  45% 157M/350M [00:00<00:00, 270MB/s]
# yolo_v8_ft.pt:  54% 189M/350M [00:00<00:00, 283MB/s]
# yolo_v8_ft.pt:  63% 220M/350M [00:00<00:00, 280MB/s]
# yolo_v8_ft.pt:  72% 252M/350M [00:00<00:00, 290MB/s]
# yolo_v8_ft.pt:  81% 283M/350M [00:01<00:00, 290MB/s]
# yolo_v8_ft.pt: 100% 350M/350M [00:01<00:00, 277MB/s]
# Fetching 1 files: 100% 1/1 [00:01<00:00,  1.40s/it]
# Fetching 7 files:   0% 0/7 [00:00<?, ?it/s]
# model.safetensors:   0% 0.00/810M [00:00<?, ?B/s]
#
# README.md: 100% 1.66k/1.66k [00:00<00:00, 13.3MB/s]
# Fetching 7 files:  14% 1/7 [00:00<00:00,  6.04it/s]
#
# tokenizer_config.json: 100% 4.52k/4.52k [00:00<00:00, 22.0MB/s]
#
#
# special_tokens_map.json: 100% 552/552 [00:00<00:00, 3.51MB/s]
#
#
# tokenizer.json:   0% 0.00/3.58M [00:00<?, ?B/s]
#
#
# config.json: 100% 5.09k/5.09k [00:00<00:00, 26.3MB/s]
#
#
#
# generation_config.json: 100% 191/191 [00:00<00:00, 1.49MB/s]
#
# model.safetensors:   3% 21.0M/810M [00:00<00:04, 196MB/s]
# model.safetensors:   8% 62.9M/810M [00:00<00:02, 284MB/s]
# model.safetensors:  13% 105M/810M [00:00<00:02, 318MB/s]
#
# tokenizer.json: 100% 3.58M/3.58M [00:00<00:00, 9.96MB/s]
#
# model.safetensors:  18% 147M/810M [00:00<00:02, 290MB/s]
# model.safetensors:  22% 178M/810M [00:00<00:02, 291MB/s]
# model.safetensors:  27% 220M/810M [00:00<00:01, 303MB/s]
# model.safetensors:  31% 252M/810M [00:00<00:01, 301MB/s]
# model.safetensors:  35% 283M/810M [00:00<00:01, 302MB/s]
# model.safetensors:  40% 325M/810M [00:01<00:01, 308MB/s]
# model.safetensors:  45% 367M/810M [00:01<00:01, 310MB/s]
# model.safetensors:  50% 409M/810M [00:01<00:01, 312MB/s]
# model.safetensors:  56% 451M/810M [00:01<00:01, 318MB/s]
# model.safetensors:  61% 493M/810M [00:01<00:00, 322MB/s]
# model.safetensors:  66% 535M/810M [00:01<00:00, 321MB/s]
# model.safetensors:  71% 577M/810M [00:01<00:00, 319MB/s]
# model.safetensors:  76% 619M/810M [00:01<00:00, 324MB/s]
# model.safetensors:  82% 661M/810M [00:02<00:00, 266MB/s]
# model.safetensors:  85% 692M/810M [00:02<00:00, 270MB/s]
# model.safetensors:  89% 724M/810M [00:02<00:00, 278MB/s]
# model.safetensors:  93% 755M/810M [00:02<00:00, 277MB/s]
# model.safetensors: 100% 810M/810M [00:02<00:00, 292MB/s]
# Fetching 7 files: 100% 7/7 [00:02<00:00,  2.39it/s]
# Fetching 1 files:   0% 0/1 [00:00<?, ?it/s]
# (…)ut_yolo_docstructbench_imgsz1280_2501.pt:   0% 0.00/39.8M [00:00<?, ?B/s]
# (…)ut_yolo_docstructbench_imgsz1280_2501.pt: 100% 39.8M/39.8M [00:00<00:00, 176MB/s]
# Fetching 1 files: 100% 1/1 [00:00<00:00,  2.40it/s]
# Fetching 1 files:   0% 0/1 [00:00<?, ?it/s]
# ch_PP-OCRv5_det_infer.pth: 100% 14.5M/14.5M [00:00<00:00, 342MB/s]
# Fetching 1 files: 100% 1/1 [00:00<00:00,  7.11it/s]
# Fetching 1 files:   0% 0/1 [00:00<?, ?it/s]
# ch_PP-OCRv4_rec_server_doc_infer.pth:   0% 0.00/101M [00:00<?, ?B/s]
# ch_PP-OCRv4_rec_server_doc_infer.pth:  31% 31.5M/101M [00:00<00:00, 302MB/s]
# ch_PP-OCRv4_rec_server_doc_infer.pth:  62% 62.9M/101M [00:00<00:00, 245MB/s]
# ch_PP-OCRv4_rec_server_doc_infer.pth: 100% 101M/101M [00:00<00:00, 230MB/s]
# Fetching 1 files: 100% 1/1 [00:00<00:00,  1.83it/s]
# Fetching 1 files:   0% 0/1 [00:00<?, ?it/s]
# slanet-plus.onnx: 100% 7.76M/7.76M [00:00<00:00, 101MB/s]
# Fetching 1 files: 100% 1/1 [00:00<00:00,  5.20it/s]
# 2025-06-13 14:30:45.585 | INFO     | mineru.backend.pipeline.model_init:__init__:182 - DocAnalysis init done!
# 2025-06-13 14:30:45.585 | INFO     | mineru.backend.pipeline.pipeline_analyze:custom_model_init:72 - model init cost: 20.85295081138611
# Layout Predict: 100% 13/13 [00:03<00:00,  4.13it/s]
# MFD Predict: 100% 13/13 [00:04<00:00,  2.81it/s]
# MFR Predict: 100% 126/126 [00:04<00:00, 25.43it/s]
# Fetching 1 files: 100% 1/1 [00:00<00:00, 17331.83it/s]
# Fetching 1 files: 100% 1/1 [00:00<00:00, 9198.04it/s]
# OCR-det ch: 100% 69/69 [00:04<00:00, 14.66it/s]
# Table Predict:   0% 0/5 [00:00<?, ?it/s]
# Fetching 1 files: 100% 1/1 [00:00<00:00, 18396.07it/s]
# Table Predict: 100% 5/5 [00:07<00:00,  1.44s/it]
# Processing pages:   0% 0/13 [00:00<?, ?it/s]
# Fetching 2 files:   0% 0/2 [00:00<?, ?it/s]
#
# model.safetensors:   0% 0.00/713M [00:00<?, ?B/s]
#
# model.safetensors:   3% 21.0M/713M [00:00<00:04, 170MB/s]
#
#
# config.json: 100% 24.1k/24.1k [00:00<00:00, 70.1MB/s]
#
# Fetching 2 files:  50% 1/2 [00:00<00:00,  3.63it/s]
#
# model.safetensors:   9% 62.9M/713M [00:00<00:02, 271MB/s]
#
# model.safetensors:  15% 105M/713M [00:00<00:02, 279MB/s]
#
# model.safetensors:  19% 136M/713M [00:00<00:02, 277MB/s]
#
# model.safetensors:  24% 168M/713M [00:00<00:01, 278MB/s]
#
# model.safetensors:  28% 199M/713M [00:00<00:01, 273MB/s]
#
# model.safetensors:  32% 231M/713M [00:00<00:01, 275MB/s]
#
# model.safetensors:  37% 262M/713M [00:00<00:01, 279MB/s]
#
# model.safetensors:  41% 294M/713M [00:01<00:01, 278MB/s]
#
# model.safetensors:  46% 325M/713M [00:01<00:01, 276MB/s]
#
# model.safetensors:  50% 357M/713M [00:01<00:01, 285MB/s]
#
# model.safetensors:  54% 388M/713M [00:01<00:01, 291MB/s]
#
# model.safetensors:  59% 419M/713M [00:01<00:01, 288MB/s]
#
# model.safetensors:  63% 451M/713M [00:01<00:00, 290MB/s]
#
# model.safetensors:  68% 482M/713M [00:01<00:00, 285MB/s]
#
# model.safetensors:  72% 514M/713M [00:01<00:00, 286MB/s]
#
# model.safetensors:  76% 545M/713M [00:01<00:00, 285MB/s]
#
# model.safetensors:  81% 577M/713M [00:02<00:00, 289MB/s]
#
# model.safetensors:  85% 608M/713M [00:02<00:00, 291MB/s]
#
# model.safetensors:  90% 640M/713M [00:02<00:00, 291MB/s]
#
# model.safetensors:  94% 671M/713M [00:02<00:00, 291MB/s]
#
# model.safetensors: 100% 713M/713M [00:02<00:00, 282MB/s]
#
# Fetching 2 files: 100% 2/2 [00:02<00:00,  1.34s/it]
# Processing pages: 100% 13/13 [00:09<00:00,  1.42it/s]
# OCR-rec Predict: 100% 7/7 [00:00<00:00, 64.42it/s]
# 2025-06-13 14:31:22.275 | INFO     | mineru.cli.common:do_parse:163 - local output dir is ./output/demo1/auto

# %%
import os
os.system("pip install pymupdf")
import fitz  # PyMuPDF
import matplotlib.pyplot as plt


import fitz  # PyMuPDF
import matplotlib.pyplot as plt
import numpy as np

# Open the PDF file
# Open the PDF file
layout = "./output/demo1/auto/demo1_layout.pdf"
spans = "./output/demo1/auto/demo1_span.pdf"
# Load and render the first page
layout_page_0 = fitz.open(layout).load_page(0)
spans_page_0 = fitz.open(spans).load_page(0)


pix1 = layout_page_0.get_pixmap()
img_array1 = np.frombuffer(pix1.samples, dtype=np.uint8).reshape(pix1.height, pix1.width, pix1.n)

# Load and render the second page
pix2 = spans_page_0.get_pixmap()
img_array2 = np.frombuffer(pix2.samples, dtype=np.uint8).reshape(pix2.height, pix2.width, pix2.n)

# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 8))

# Display the first image
axes[0].imshow(img_array1)
axes[0].axis('off')

# Display the second image
axes[1].imshow(img_array2)
axes[1].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### **Convert Batch PDF**

# %%
# !mineru -p ./ -o ./output
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749825311.546169    3374 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749825311.552054    3374 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-13 14:35:14.283 | WARNING  | mineru.backend.vlm.predictor:<module>:35 - sglang is not installed. If you are not using sglang, you can ignore this warning.
# 2025-06-13 14:35:20.711 | INFO     | mineru.backend.pipeline.pipeline_analyze:doc_analyze:128 - Batch 1/1: 19 pages/19 pages
# 2025-06-13 14:35:20.712 | INFO     | mineru.backend.pipeline.pipeline_analyze:batch_image_analyze:191 - gpu_memory: 15 GB, batch_ratio: 8
# 2025-06-13 14:35:20.712 | INFO     | mineru.backend.pipeline.model_init:__init__:137 - DocAnalysis init, this may take some times......
# Fetching 1 files: 100% 1/1 [00:00<00:00, 12018.06it/s]
# Fetching 7 files: 100% 7/7 [00:00<00:00, 10489.51it/s]
# Fetching 1 files: 100% 1/1 [00:00<00:00, 15141.89it/s]
# Fetching 1 files: 100% 1/1 [00:00<00:00, 15363.75it/s]
# Fetching 1 files: 100% 1/1 [00:00<00:00, 8665.92it/s]
# Fetching 1 files: 100% 1/1 [00:00<00:00, 8112.77it/s]
# 2025-06-13 14:35:26.962 | INFO     | mineru.backend.pipeline.model_init:__init__:182 - DocAnalysis init done!
# 2025-06-13 14:35:26.962 | INFO     | mineru.backend.pipeline.pipeline_analyze:custom_model_init:72 - model init cost: 6.2502782344818115
# Layout Predict: 100% 19/19 [00:03<00:00,  4.83it/s]
# MFD Predict: 100% 19/19 [00:08<00:00,  2.29it/s]
# MFR Predict: 100% 222/222 [00:09<00:00, 22.81it/s]
# Fetching 1 files: 100% 1/1 [00:00<00:00, 16513.01it/s]
# Fetching 1 files: 100% 1/1 [00:00<00:00, 2959.99it/s]
# OCR-det ch: 100% 101/101 [00:07<00:00, 13.78it/s]
# Table Predict:   0% 0/7 [00:00<?, ?it/s]
# Fetching 1 files: 100% 1/1 [00:00<00:00, 3086.32it/s]
# Table Predict: 100% 7/7 [00:07<00:00,  1.12s/it]
# Processing pages:   0% 0/6 [00:00<?, ?it/s]
# Fetching 2 files: 100% 2/2 [00:00<00:00, 32017.59it/s]
# Processing pages: 100% 6/6 [00:04<00:00,  1.28it/s]
# 2025-06-13 14:36:11.576 | INFO     | mineru.cli.common:do_parse:163 - local output dir is ./output/demo2/auto
# Processing pages: 100% 13/13 [00:04<00:00,  3.10it/s]
# OCR-rec Predict: 100% 7/7 [00:00<00:00, 99.85it/s]
# 2025-06-13 14:36:16.692 | INFO     | mineru.cli.common:do_parse:163 - local output dir is ./output/demo1/auto

# %%
import fitz  # PyMuPDF
import matplotlib.pyplot as plt


import fitz  # PyMuPDF
import matplotlib.pyplot as plt
import numpy as np

# Open the PDF file
# Open the PDF file
layout1 = "output/demo1/auto/demo1_layout.pdf"
layout2 = "output/demo2/auto/demo2_layout.pdf"
# Load and render the first page
layout1_page_0 = fitz.open(layout1).load_page(0)
layout2_page_0 = fitz.open(layout2).load_page(0)


pix1 = layout_page_0.get_pixmap()
img_array1 = np.frombuffer(pix1.samples, dtype=np.uint8).reshape(pix1.height, pix1.width, pix1.n)

# Load and render the second page
pix2 = layout2_page_0.get_pixmap()
img_array2 = np.frombuffer(pix2.samples, dtype=np.uint8).reshape(pix2.height, pix2.width, pix2.n)

# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 8))

# Display the first image
axes[0].imshow(img_array1)
axes[0].axis('off')

# Display the second image
axes[1].imshow(img_array2)
axes[1].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.2API

# %% [markdown]
# #### **Simplest Convertion**

# %%
# Copyright (c) Opendatalab. All rights reserved.
import copy
import json
import os
from pathlib import Path

from loguru import logger

from mineru.cli.common import convert_pdf_bytes_to_bytes_by_pypdfium2, prepare_env, read_fn
from mineru.data.data_reader_writer import FileBasedDataWriter
from mineru.utils.draw_bbox import draw_layout_bbox, draw_span_bbox
from mineru.utils.enum_class import MakeMode
from mineru.backend.vlm.vlm_analyze import doc_analyze as vlm_doc_analyze
from mineru.backend.pipeline.pipeline_analyze import doc_analyze as pipeline_doc_analyze
from mineru.backend.pipeline.pipeline_middle_json_mkcontent import union_make as pipeline_union_make
from mineru.backend.pipeline.model_json_to_middle_json import result_to_middle_json as pipeline_result_to_middle_json
from mineru.backend.vlm.vlm_middle_json_mkcontent import union_make as vlm_union_make
from mineru.utils.models_download_utils import auto_download_and_get_model_root_path


def do_parse(
    output_dir,  # Output directory for storing parsing results
    pdf_file_names: list[str],  # List of PDF file names to be parsed
    pdf_bytes_list: list[bytes],  # List of PDF bytes to be parsed
    p_lang_list: list[str],  # List of languages for each PDF, default is 'ch' (Chinese)
    backend="pipeline",  # The backend for parsing PDF, default is 'pipeline'
    parse_method="auto",  # The method for parsing PDF, default is 'auto'
    p_formula_enable=True,  # Enable formula parsing
    p_table_enable=True,  # Enable table parsing
    server_url=None,  # Server URL for vlm-sglang-client backend
    f_draw_layout_bbox=True,  # Whether to draw layout bounding boxes
    f_draw_span_bbox=True,  # Whether to draw span bounding boxes
    f_dump_md=True,  # Whether to dump markdown files
    f_dump_middle_json=True,  # Whether to dump middle JSON files
    f_dump_model_output=True,  # Whether to dump model output files
    f_dump_orig_pdf=True,  # Whether to dump original PDF files
    f_dump_content_list=True,  # Whether to dump content list files
    f_make_md_mode=MakeMode.MM_MD,  # The mode for making markdown content, default is MM_MD
    start_page_id=0,  # Start page ID for parsing, default is 0
    end_page_id=None,  # End page ID for parsing, default is None (parse all pages until the end of the document)
):

    if backend == "pipeline":
        for idx, pdf_bytes in enumerate(pdf_bytes_list):
            new_pdf_bytes = convert_pdf_bytes_to_bytes_by_pypdfium2(pdf_bytes, start_page_id, end_page_id)
            pdf_bytes_list[idx] = new_pdf_bytes

        infer_results, all_image_lists, all_pdf_docs, lang_list, ocr_enabled_list = pipeline_doc_analyze(pdf_bytes_list, p_lang_list, parse_method=parse_method, formula_enable=p_formula_enable,table_enable=p_table_enable)

        for idx, model_list in enumerate(infer_results):
            model_json = copy.deepcopy(model_list)
            pdf_file_name = pdf_file_names[idx]
            local_image_dir, local_md_dir = prepare_env(output_dir, pdf_file_name, parse_method)
            image_writer, md_writer = FileBasedDataWriter(local_image_dir), FileBasedDataWriter(local_md_dir)

            images_list = all_image_lists[idx]
            pdf_doc = all_pdf_docs[idx]
            _lang = lang_list[idx]
            _ocr_enable = ocr_enabled_list[idx]
            middle_json = pipeline_result_to_middle_json(model_list, images_list, pdf_doc, image_writer, _lang, _ocr_enable, p_formula_enable)

            pdf_info = middle_json["pdf_info"]

            pdf_bytes = pdf_bytes_list[idx]
            if f_draw_layout_bbox:
                draw_layout_bbox(pdf_info, pdf_bytes, local_md_dir, f"{pdf_file_name}_layout.pdf")

            if f_draw_span_bbox:
                draw_span_bbox(pdf_info, pdf_bytes, local_md_dir, f"{pdf_file_name}_span.pdf")

            if f_dump_orig_pdf:
                md_writer.write(
                    f"{pdf_file_name}_origin.pdf",
                    pdf_bytes,
                )

            if f_dump_md:
                image_dir = str(os.path.basename(local_image_dir))
                md_content_str = pipeline_union_make(pdf_info, f_make_md_mode, image_dir)
                md_writer.write_string(
                    f"{pdf_file_name}.md",
                    md_content_str,
                )

            if f_dump_content_list:
                image_dir = str(os.path.basename(local_image_dir))
                content_list = pipeline_union_make(pdf_info, MakeMode.CONTENT_LIST, image_dir)
                md_writer.write_string(
                    f"{pdf_file_name}_content_list.json",
                    json.dumps(content_list, ensure_ascii=False, indent=4),
                )

            if f_dump_middle_json:
                md_writer.write_string(
                    f"{pdf_file_name}_middle.json",
                    json.dumps(middle_json, ensure_ascii=False, indent=4),
                )

            if f_dump_model_output:
                md_writer.write_string(
                    f"{pdf_file_name}_model.json",
                    json.dumps(model_json, ensure_ascii=False, indent=4),
                )

            logger.info(f"local output dir is {local_md_dir}")
    else:
        if backend.startswith("vlm-"):
            backend = backend[4:]

        f_draw_span_bbox = False
        parse_method = "vlm"
        for idx, pdf_bytes in enumerate(pdf_bytes_list):
            pdf_file_name = pdf_file_names[idx]
            pdf_bytes = convert_pdf_bytes_to_bytes_by_pypdfium2(pdf_bytes, start_page_id, end_page_id)
            local_image_dir, local_md_dir = prepare_env(output_dir, pdf_file_name, parse_method)
            image_writer, md_writer = FileBasedDataWriter(local_image_dir), FileBasedDataWriter(local_md_dir)
            middle_json, infer_result = vlm_doc_analyze(pdf_bytes, image_writer=image_writer, backend=backend, server_url=server_url)

            pdf_info = middle_json["pdf_info"]

            if f_draw_layout_bbox:
                draw_layout_bbox(pdf_info, pdf_bytes, local_md_dir, f"{pdf_file_name}_layout.pdf")

            if f_draw_span_bbox:
                draw_span_bbox(pdf_info, pdf_bytes, local_md_dir, f"{pdf_file_name}_span.pdf")

            if f_dump_orig_pdf:
                md_writer.write(
                    f"{pdf_file_name}_origin.pdf",
                    pdf_bytes,
                )

            if f_dump_md:
                image_dir = str(os.path.basename(local_image_dir))
                md_content_str = vlm_union_make(pdf_info, f_make_md_mode, image_dir)
                md_writer.write_string(
                    f"{pdf_file_name}.md",
                    md_content_str,
                )

            if f_dump_content_list:
                image_dir = str(os.path.basename(local_image_dir))
                content_list = vlm_union_make(pdf_info, MakeMode.CONTENT_LIST, image_dir)
                md_writer.write_string(
                    f"{pdf_file_name}_content_list.json",
                    json.dumps(content_list, ensure_ascii=False, indent=4),
                )

            if f_dump_middle_json:
                md_writer.write_string(
                    f"{pdf_file_name}_middle.json",
                    json.dumps(middle_json, ensure_ascii=False, indent=4),
                )

            if f_dump_model_output:
                model_output = ("\n" + "-" * 50 + "\n").join(infer_result)
                md_writer.write_string(
                    f"{pdf_file_name}_model_output.txt",
                    model_output,
                )

            logger.info(f"local output dir is {local_md_dir}")


def parse_doc(
        path_list: list[Path],
        output_dir,
        lang="ch",
        backend="pipeline",
        method="auto",
        server_url=None,
        start_page_id=0,  # Start page ID for parsing, default is 0
        end_page_id=None  # End page ID for parsing, default is None (parse all pages until the end of the document)
):
    """
        Parameter description:
        path_list: List of document paths to be parsed, can be PDF or image files.
        output_dir: Output directory for storing parsing results.
        lang: Language option, default is 'ch', optional values include['ch', 'ch_server', 'ch_lite', 'en', 'korean', 'japan', 'chinese_cht', 'ta', 'te', 'ka']。
            Input the languages in the pdf (if known) to improve OCR accuracy.  Optional.
            Adapted only for the case where the backend is set to "pipeline"
        backend: the backend for parsing pdf:
            pipeline: More general.
            vlm-transformers: More general.
            vlm-sglang-engine: Faster(engine).
            vlm-sglang-client: Faster(client).
            without method specified, pipeline will be used by default.
        method: the method for parsing pdf:
            auto: Automatically determine the method based on the file type.
            txt: Use text extraction method.
            ocr: Use OCR method for image-based PDFs.
            Without method specified, 'auto' will be used by default.
            Adapted only for the case where the backend is set to "pipeline".
        server_url: When the backend is `sglang-client`, you need to specify the server_url, for example:`http://127.0.0.1:30000`
    """
    try:
        file_name_list = []
        pdf_bytes_list = []
        lang_list = []
        for path in path_list:
            file_name = str(Path(path).stem)
            pdf_bytes = read_fn(path)
            file_name_list.append(file_name)
            pdf_bytes_list.append(pdf_bytes)
            lang_list.append(lang)
        do_parse(
            output_dir=output_dir,
            pdf_file_names=file_name_list,
            pdf_bytes_list=pdf_bytes_list,
            p_lang_list=lang_list,
            backend=backend,
            parse_method=method,
            server_url=server_url,
            start_page_id=start_page_id,
            end_page_id=end_page_id
        )
    except Exception as e:
        logger.exception(e)


if __name__ == '__main__':
    # args
    pdf_files_dir = "./"
    output_dir = os.path.join(pdf_files_dir, "output")
    pdf_suffixes = [".pdf"]
    image_suffixes = [".png", ".jpeg", ".jpg"]

    doc_path_list = []
    for doc_path in Path(pdf_files_dir).glob('*'):
        if doc_path.suffix in pdf_suffixes + image_suffixes:
            doc_path_list.append(doc_path)

    """如果您由于网络问题无法下载模型，可以设置环境变量MINERU_MODEL_SOURCE为modelscope使用免代理仓库下载模型"""
    # os.environ['MINERU_MODEL_SOURCE'] = "modelscope"

    """Use pipeline mode if your environment does not support VLM"""
    parse_doc(doc_path_list, output_dir, backend="pipeline")

    """To enable VLM mode, change the backend to 'vlm-xxx'"""
    # parse_doc(doc_path_list, output_dir, backend="vlm-transformers")  # more general.
    # parse_doc(doc_path_list, output_dir, backend="vlm-sglang-engine")  # faster(engine).
    # parse_doc(doc_path_list, output_dir, backend="vlm-sglang-client", server_url="http://127.0.0.1:30000"）  # faster(client).
# Out:
# 2025-06-13 14:40:16.386 | INFO     | mineru.backend.pipeline.pipeline_analyze:doc_analyze:128 - Batch 1/1: 19 pages/19 pages
# 2025-06-13 14:40:16.390 | INFO     | mineru.backend.pipeline.pipeline_analyze:batch_image_analyze:191 - gpu_memory: 15 GB, batch_ratio: 8
# 2025-06-13 14:40:16.390 | INFO     | mineru.backend.pipeline.model_init:__init__:137 - DocAnalysis init, this may take some times......
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching 7 files:   0%|          | 0/7 [00:00<?, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-06-13 14:40:23.838 | INFO     | mineru.backend.pipeline.model_init:__init__:182 - DocAnalysis init done!
# 2025-06-13 14:40:23.839 | INFO     | mineru.backend.pipeline.pipeline_analyze:custom_model_init:72 - model init cost: 7.448789119720459
# Layout Predict: 100%|██████████| 19/19 [00:04<00:00,  4.32it/s]
# MFD Predict: 100%|██████████| 19/19 [00:06<00:00,  3.03it/s]
# MFR Predict: 100%|██████████| 222/222 [00:09<00:00, 24.05it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# OCR-det ch: 100%|██████████| 101/101 [00:07<00:00, 12.99it/s]
# Table Predict:   0%|          | 0/7 [00:00<?, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Table Predict: 100%|██████████| 7/7 [00:08<00:00,  1.17s/it]
# Processing pages:   0%|          | 0/6 [00:00<?, ?it/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Processing pages: 100%|██████████| 6/6 [00:04<00:00,  1.40it/s]
# 2025-06-13 14:41:06.744 | INFO     | __main__:do_parse:105 - local output dir is ./output/demo2/auto
# Processing pages: 100%|██████████| 13/13 [00:04<00:00,  2.87it/s]
# OCR-rec Predict: 100%|██████████| 7/7 [00:00<00:00, 59.26it/s]
# 2025-06-13 14:41:12.654 | INFO     | __main__:do_parse:105 - local output dir is ./output/demo1/auto
