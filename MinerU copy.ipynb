# %%
#do on command line in conda env
# !setopt no_nomatch

# %%
#do on command line in conda env
#!pip install -U magic-pdf[full] --extra-index-url https://wheels.myhloli.com
# !pip install -U "magic-pdf[full]"
# Out:
# Requirement already satisfied: magic-pdf[full] in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (1.3.11)
# Collecting magic-pdf[full]
#   Downloading magic_pdf-1.3.12-py3-none-any.whl.metadata (49 kB)
# Requirement already satisfied: Brotli>=1.1.0 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from magic-pdf[full]) (1.1.0)
# Requirement already satisfied: PyMuPDF<1.25.0,>=1.24.9 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from magic-pdf[full]) (1.24.14)
# Requirement already satisfied: boto3>=1.28.43 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from magic-pdf[full]) (1.38.11)
# Requirement already satisfied: click>=8.1.7 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from magic-pdf[full]) (8.1.8)
# Requirement already satisfied: fast-langdetect<0.3.0,>=0.2.3 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from magic-pdf[full]) (0.2.5)
# Requirement already satisfied: loguru>=0.6.0 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from magic-pdf[full]) (0.7.3)
# Requirement already satisfied: numpy>=1.21.6 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from magic-pdf[full]) (2.2.5)
# Requirement already satisfied: pdfminer.six==20250506 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from magic-pdf[full]) (20250506)
# Requirement already satisfied: pydantic<2.11,>=2.7.2 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from magic-pdf[full]) (2.10.6)
# Requirement already satisfied: scikit-learn>=1.0.2 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from magic-pdf[full]) (1.6.1)
# Requirement already satisfied: torch!=2.5.0,!=2.5.1,<3,>=2.2.2 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from magic-pdf[full]) (2.7.0)
# Requirement already satisfied: torchvision in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from magic-pdf[full]) (0.22.0)
# Requirement already satisfied: tqdm>=4.67.1 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from magic-pdf[full]) (4.67.1)
# Requirement already satisfied: transformers!=4.51.0,<5.0.0,>=4.49.0 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from magic-pdf[full]) (4.51.3)
# Requirement already satisfied: PyYAML<7,>=6.0.2 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from magic-pdf[full]) (6.0.2)
# Requirement already satisfied: dill<1,>=0.3.8 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from magic-pdf[full]) (0.4.0)
# Requirement already satisfied: doclayout-yolo==0.0.2b1 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from magic-pdf[full]) (0.0.2b1)
# Requirement already satisfied: ftfy<7,>=6.3.1 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from magic-pdf[full]) (6.3.1)
# Requirement already satisfied: matplotlib<4,>=3.10 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from magic-pdf[full]) (3.10.1)
# Requirement already satisfied: omegaconf<3,>=2.3.0 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from magic-pdf[full]) (2.3.0)
# Requirement already satisfied: openai<2,>=1.70.0 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from magic-pdf[full]) (1.77.0)
# Requirement already satisfied: pyclipper<2,>=1.3.0 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from magic-pdf[full]) (1.3.0.post6)
# Requirement already satisfied: rapid-table<2.0.0,>=1.0.5 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from magic-pdf[full]) (1.0.5)
# Requirement already satisfied: shapely<3,>=2.0.7 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from magic-pdf[full]) (2.1.0)
# Requirement already satisfied: ultralytics<9,>=8.3.48 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from magic-pdf[full]) (8.3.128)
# Requirement already satisfied: opencv-python>=4.6.0 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from doclayout-yolo==0.0.2b1->magic-pdf[full]) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from doclayout-yolo==0.0.2b1->magic-pdf[full]) (11.2.1)
# Requirement already satisfied: requests>=2.23.0 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from doclayout-yolo==0.0.2b1->magic-pdf[full]) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from doclayout-yolo==0.0.2b1->magic-pdf[full]) (1.15.2)
# Requirement already satisfied: psutil in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from doclayout-yolo==0.0.2b1->magic-pdf[full]) (7.0.0)
# Requirement already satisfied: py-cpuinfo in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from doclayout-yolo==0.0.2b1->magic-pdf[full]) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from doclayout-yolo==0.0.2b1->magic-pdf[full]) (0.1.1.post2209072238)
# Requirement already satisfied: pandas>=1.1.4 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from doclayout-yolo==0.0.2b1->magic-pdf[full]) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from doclayout-yolo==0.0.2b1->magic-pdf[full]) (0.13.2)
# Requirement already satisfied: albumentations>=1.4.11 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from doclayout-yolo==0.0.2b1->magic-pdf[full]) (2.0.6)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from pdfminer.six==20250506->magic-pdf[full]) (3.4.2)
# Requirement already satisfied: cryptography>=36.0.0 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from pdfminer.six==20250506->magic-pdf[full]) (44.0.3)
# Requirement already satisfied: robust-downloader>=0.0.2 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from fast-langdetect<0.3.0,>=0.2.3->magic-pdf[full]) (0.0.2)
# Requirement already satisfied: fasttext-predict>=0.9.2.4 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from fast-langdetect<0.3.0,>=0.2.3->magic-pdf[full]) (0.9.2.4)
# Requirement already satisfied: wcwidth in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from ftfy<7,>=6.3.1->magic-pdf[full]) (0.2.13)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from matplotlib<4,>=3.10->magic-pdf[full]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from matplotlib<4,>=3.10->magic-pdf[full]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from matplotlib<4,>=3.10->magic-pdf[full]) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from matplotlib<4,>=3.10->magic-pdf[full]) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from matplotlib<4,>=3.10->magic-pdf[full]) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from matplotlib<4,>=3.10->magic-pdf[full]) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from matplotlib<4,>=3.10->magic-pdf[full]) (2.9.0.post0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from omegaconf<3,>=2.3.0->magic-pdf[full]) (4.9.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from openai<2,>=1.70.0->magic-pdf[full]) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from openai<2,>=1.70.0->magic-pdf[full]) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from openai<2,>=1.70.0->magic-pdf[full]) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from openai<2,>=1.70.0->magic-pdf[full]) (0.9.0)
# Requirement already satisfied: sniffio in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from openai<2,>=1.70.0->magic-pdf[full]) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from openai<2,>=1.70.0->magic-pdf[full]) (4.13.2)
# Requirement already satisfied: idna>=2.8 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai<2,>=1.70.0->magic-pdf[full]) (3.10)
# Requirement already satisfied: certifi in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai<2,>=1.70.0->magic-pdf[full]) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai<2,>=1.70.0->magic-pdf[full]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2,>=1.70.0->magic-pdf[full]) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from pydantic<2.11,>=2.7.2->magic-pdf[full]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from pydantic<2.11,>=2.7.2->magic-pdf[full]) (2.27.2)
# Requirement already satisfied: onnxruntime>1.17.0 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from rapid-table<2.0.0,>=1.0.5->magic-pdf[full]) (1.21.1)
# Requirement already satisfied: colorlog in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from rapid-table<2.0.0,>=1.0.5->magic-pdf[full]) (6.9.0)
# Requirement already satisfied: filelock in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from torch!=2.5.0,!=2.5.1,<3,>=2.2.2->magic-pdf[full]) (3.18.0)
# Requirement already satisfied: setuptools in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from torch!=2.5.0,!=2.5.1,<3,>=2.2.2->magic-pdf[full]) (80.1.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from torch!=2.5.0,!=2.5.1,<3,>=2.2.2->magic-pdf[full]) (1.14.0)
# Requirement already satisfied: networkx in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from torch!=2.5.0,!=2.5.1,<3,>=2.2.2->magic-pdf[full]) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from torch!=2.5.0,!=2.5.1,<3,>=2.2.2->magic-pdf[full]) (3.1.6)
# Requirement already satisfied: fsspec in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from torch!=2.5.0,!=2.5.1,<3,>=2.2.2->magic-pdf[full]) (2025.3.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from transformers!=4.51.0,<5.0.0,>=4.49.0->magic-pdf[full]) (0.31.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from transformers!=4.51.0,<5.0.0,>=4.49.0->magic-pdf[full]) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from transformers!=4.51.0,<5.0.0,>=4.49.0->magic-pdf[full]) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from transformers!=4.51.0,<5.0.0,>=4.49.0->magic-pdf[full]) (0.5.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.0 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers!=4.51.0,<5.0.0,>=4.49.0->magic-pdf[full]) (1.1.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from ultralytics<9,>=8.3.48->magic-pdf[full]) (2.0.14)
# Requirement already satisfied: albucore==0.0.24 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from albumentations>=1.4.11->doclayout-yolo==0.0.2b1->magic-pdf[full]) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from albumentations>=1.4.11->doclayout-yolo==0.0.2b1->magic-pdf[full]) (4.11.0.86)
# Requirement already satisfied: stringzilla>=3.10.4 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from albucore==0.0.24->albumentations>=1.4.11->doclayout-yolo==0.0.2b1->magic-pdf[full]) (3.12.5)
# Requirement already satisfied: simsimd>=5.9.2 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from albucore==0.0.24->albumentations>=1.4.11->doclayout-yolo==0.0.2b1->magic-pdf[full]) (6.2.1)
# Requirement already satisfied: botocore<1.39.0,>=1.38.11 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from boto3>=1.28.43->magic-pdf[full]) (1.38.11)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from boto3>=1.28.43->magic-pdf[full]) (1.0.1)
# Requirement already satisfied: s3transfer<0.13.0,>=0.12.0 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from boto3>=1.28.43->magic-pdf[full]) (0.12.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from botocore<1.39.0,>=1.38.11->boto3>=1.28.43->magic-pdf[full]) (2.4.0)
# Requirement already satisfied: six>=1.5 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.10->magic-pdf[full]) (1.17.0)
# Requirement already satisfied: cffi>=1.12 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from cryptography>=36.0.0->pdfminer.six==20250506->magic-pdf[full]) (1.17.1)
# Requirement already satisfied: pycparser in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20250506->magic-pdf[full]) (2.22)
# Requirement already satisfied: coloredlogs in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from onnxruntime>1.17.0->rapid-table<2.0.0,>=1.0.5->magic-pdf[full]) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from onnxruntime>1.17.0->rapid-table<2.0.0,>=1.0.5->magic-pdf[full]) (25.2.10)
# Requirement already satisfied: protobuf in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from onnxruntime>1.17.0->rapid-table<2.0.0,>=1.0.5->magic-pdf[full]) (6.30.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from pandas>=1.1.4->doclayout-yolo==0.0.2b1->magic-pdf[full]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from pandas>=1.1.4->doclayout-yolo==0.0.2b1->magic-pdf[full]) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from scikit-learn>=1.0.2->magic-pdf[full]) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from scikit-learn>=1.0.2->magic-pdf[full]) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from sympy>=1.13.3->torch!=2.5.0,!=2.5.1,<3,>=2.2.2->magic-pdf[full]) (1.3.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from coloredlogs->onnxruntime>1.17.0->rapid-table<2.0.0,>=1.0.5->magic-pdf[full]) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/lukasfiller/miniforge3/envs/mineru/lib/python3.12/site-packages (from jinja2->torch!=2.5.0,!=2.5.1,<3,>=2.2.2->magic-pdf[full]) (3.0.2)
# Downloading magic_pdf-1.3.12-py3-none-any.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 6.6 MB/s eta 0:00:00ta 0:00:01
# Installing collected packages: magic-pdf
#   Attempting uninstall: magic-pdf
#     Found existing installation: magic-pdf 1.3.11
#     Uninstalling magic-pdf-1.3.11:
#       Successfully uninstalled magic-pdf-1.3.11
# Successfully installed magic-pdf-1.3.12

# %%
# !pip install -U magic-pdf[full] --extra-index-url https://wheels.myhloli.com -i https://mirrors.aliyun.com/pypi/simple
# Out:
# zsh:1: no matches found: magic-pdf[full]

# %%
# !magic-pdf -v
# !pwd
# Out:
# magic-pdf, version 1.3.12
# /Users/lukasfiller/dev/MinerU

# %% [markdown]
# modify magic-pdf.json config

# %% [markdown]
# I guess you could change the model in magic_pdf/config/constants.py
#
# # pp detect model dir
# DETECT_MODEL_DIR = 'ch_PP-OCRv4_det_infer'
#
# # pp rec model dir
# REC_MODEL_DIR = 'ch_PP-OCRv4_rec_infer'
#
# # pp rec char dict path
# REC_CHAR_DICT = 'ppocr_keys_v1.txt'
#
# # pp rec copy rec directory
# PP_REC_DIRECTORY = '.paddleocr/whl/rec/ch/ch_PP-OCRv4_rec_infer'
#
# # pp rec copy det directory
# PP_DET_DIRECTORY = '.paddleocr/whl/det/ch/ch_PP-OCRv4_det_infer'

# %%
#!pip install huggingface_hub
#!wget https://gitee.com/myhloli/MinerU/raw/master/scripts/download_models_hf.py -O download_models_hf.py
# !wget https://github.com/opendatalab/MinerU/raw/master/scripts/download_models_hf.py -O download_models_hf.py

#!wget https://github.com/opendatalab/MinerU/scripts/download_models_hf.py -O download_models_hf.py
#!wget https://raw.githubusercontent.com/opendatalab/MinerU/refs/heads/master/scripts/download_models_hf.py -O download_models_hf.py
# !python download_models_hf.py
# Out:
# --2025-05-28 15:35:40--  https://github.com/opendatalab/MinerU/raw/master/scripts/download_models_hf.py
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/opendatalab/MinerU/master/scripts/download_models_hf.py [following]
# --2025-05-28 15:35:40--  https://raw.githubusercontent.com/opendatalab/MinerU/master/scripts/download_models_hf.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2386 (2.3K) [text/plain]
# Saving to: ‘download_models_hf.py’
#
# download_models_hf. 100%[===================>]   2.33K  --.-KB/s    in 0s
#
# 2025-05-28 15:35:41 (49.5 MB/s) - ‘download_models_hf.py’ saved [2386/2386]
#
# Fetching 33 files:   3%|▊                        | 1/33 [00:01<00:47,  1.48s/it]
# ch_PP-OCRv5_rec_infer.pth:   0%|                    | 0.00/32.6M [00:00<?, ?B/s]
#
# ch_PP-OCRv5_det_infer.pth:   0%|                    | 0.00/14.5M [00:00<?, ?B/s]
#
#
# ch_PP-OCRv5_rec_server_infer.pth:   0%|              | 0.00/135M [00:00<?, ?B/s]
#
# ch_PP-OCRv5_det_infer.pth:  72%|███████▉   | 10.5M/14.5M [00:01<00:00, 8.74MB/s]
#
#
# ch_PP-OCRv5_rec_server_infer.pth:   8%|▍    | 10.5M/135M [00:01<00:20, 5.94MB/s]
# ch_PP-OCRv5_rec_infer.pth:  32%|███▌       | 10.5M/32.6M [00:01<00:03, 5.64MB/s]
#
# ch_PP-OCRv5_det_infer.pth: 100%|███████████| 14.5M/14.5M [00:02<00:00, 6.35MB/s]
# Fetching 33 files:  58%|█████████████▊          | 19/33 [00:03<00:02,  5.59it/s]
#
#
# ch_PP-OCRv5_rec_server_infer.pth:  16%|▊    | 21.0M/135M [00:02<00:13, 8.58MB/s]
# ch_PP-OCRv5_rec_infer.pth:  64%|███████    | 21.0M/32.6M [00:02<00:01, 7.87MB/s]
#
#
# ch_PP-OCRv5_rec_server_infer.pth:  23%|█▏   | 31.5M/135M [00:03<00:09, 10.7MB/s]
# ch_PP-OCRv5_rec_infer.pth: 100%|███████████| 32.6M/32.6M [00:03<00:00, 9.00MB/s]
# Fetching 33 files:  61%|██████████████▌         | 20/33 [00:05<00:03,  3.83it/s]
#
#
# ch_PP-OCRv5_rec_server_infer.pth:  31%|█▌   | 41.9M/135M [00:03<00:07, 12.6MB/s]
#
#
# ch_PP-OCRv5_rec_server_infer.pth:  39%|█▉   | 52.4M/135M [00:04<00:05, 14.6MB/s]
#
#
# ch_PP-OCRv5_rec_server_infer.pth:  47%|██▎  | 62.9M/135M [00:04<00:04, 16.9MB/s]
#
#
# ch_PP-OCRv5_rec_server_infer.pth:  55%|██▋  | 73.4M/135M [00:05<00:03, 18.4MB/s]
#
#
# ch_PP-OCRv5_rec_server_infer.pth:  62%|███  | 83.9M/135M [00:05<00:02, 21.9MB/s]
#
#
# ch_PP-OCRv5_rec_server_infer.pth:  70%|███▌ | 94.4M/135M [00:05<00:01, 24.6MB/s]
#
#
# ch_PP-OCRv5_rec_server_infer.pth:  78%|████▋ | 105M/135M [00:06<00:01, 25.8MB/s]
#
#
# ch_PP-OCRv5_rec_server_infer.pth:  86%|█████▏| 115M/135M [00:06<00:00, 28.1MB/s]
#
#
# ch_PP-OCRv5_rec_server_infer.pth:  93%|█████▌| 126M/135M [00:06<00:00, 28.5MB/s]
#
#
# ch_PP-OCRv5_rec_server_infer.pth: 100%|██████| 135M/135M [00:07<00:00, 18.7MB/s]
# Fetching 33 files: 100%|████████████████████████| 33/33 [00:08<00:00,  3.80it/s]
# Fetching 2 files: 100%|████████████████████████| 2/2 [00:00<00:00, 25266.89it/s]
# model_dir is: /Users/lukasfiller/.cache/huggingface/hub/models--opendatalab--PDF-Extract-Kit-1.0/snapshots/94736d90d98216c30edeef5577ae89a7be656bf5/models
# layoutreader_model_dir is: /Users/lukasfiller/.cache/huggingface/hub/models--hantian--layoutreader/snapshots/641226775a0878b1014a96ad01b9642915136853
# The configuration file has been configured successfully, the path is: /Users/lukasfiller/magic-pdf.json

# %% [markdown]
# go to lukasfiller/magic-pdf.json to configure
#
# "device-mode": "mps"
#
# and also
#
#
#     // other config
#     "layout-config": {
#         "model": "doclayout_yolo" // Please change to "layoutlmv3" when using layoutlmv3. ****no longer compatible? 17APR2025
#     },
#     "formula-config": {
#         "mfd_model": "yolo_v8_mfd",
#         "mfr_model": "unimernet_small",
#         "enable": true  // The formula recognition feature is enabled by default. If you need to disable it, please change the value here to "false".
#     },
#     "table-config": {
#         "model": "rapid_table",  // Default to using "rapid_table", can be switched to "tablemaster" or "struct_eqtable". tablemaster may be best?
#         "enable": true, // The table recognition feature is enabled by default. If you need to disable it, please change the value here to "false".
#         "max_time": 400

# %%
#running locally
#use ch for chinese & english
# !magic-pdf -p """/Users/lukasfiller/Library/CloudStorage/OneDrive-DKIAsia-PacificCenterforSecurityStudies/APCSS_Docs/topics/Cognitive Warfare/Decoding-Chinas-AI-Powered-Algorithmic-Cognitive-Warfare-Final.pdf""" -o ""/Users/lukasfiller/mineru/"" -m auto -l ch -d True
# Out:
# 2025-05-28 17:12:14.561 | WARNING  | magic_pdf.libs.config_reader:get_latex_delimiter_config:132 - 'latex-delimiter-config' not found in magic-pdf.json, use 'None' as default
# 2025-05-28 17:12:17.733 | WARNING  | magic_pdf.tools.common:_do_parse:97 - debug mode is on
# 2025-05-28 17:12:17.744 | INFO     | magic_pdf.data.dataset:__init__:157 - lang: ch
# 2025-05-28 17:12:18.032 | INFO     | magic_pdf.libs.pdf_check:detect_invalid_chars:67 - cid_count: 0, text_len: 22763, cid_chars_radio: 0.0
# 2025-05-28 17:12:18.139 | INFO     | magic_pdf.model.doc_analyze_by_custom_model:doc_analyze:162 - Batch 1/1: 11 pages/11 pages
# 2025-05-28 17:12:18.141 | INFO     | magic_pdf.model.pdf_extract_kit:__init__:68 - DocAnalysis init, this may take some times, layout_model: doclayout_yolo, apply_formula: True, apply_ocr: True, apply_table: True, table_model: rapid_table, lang: None
# 2025-05-28 17:12:18.141 | INFO     | magic_pdf.model.pdf_extract_kit:__init__:82 - using device: mps
# 2025-05-28 17:12:18.141 | INFO     | magic_pdf.model.pdf_extract_kit:__init__:86 - using models_dir: /Users/lukasfiller/.cache/huggingface/hub/models--opendatalab--PDF-Extract-Kit-1.0/snapshots/94736d90d98216c30edeef5577ae89a7be656bf5/models
# 2025-05-28 17:12:22.762 | INFO     | magic_pdf.model.pdf_extract_kit:__init__:164 - DocAnalysis init done!
# 2025-05-28 17:12:22.762 | INFO     | magic_pdf.model.doc_analyze_by_custom_model:custom_model_init:116 - model init cost: 4.621915817260742
# Layout Predict: 100%|███████████████████████████| 11/11 [00:01<00:00,  6.05it/s]
# MFD Predict: 100%|██████████████████████████████| 11/11 [00:01<00:00,  6.30it/s]
# MFR Predict: 0it [00:00, ?it/s]
# OCR-det Predict: 100%|██████████████████████████| 11/11 [00:21<00:00,  1.92s/it]
# Table Predict: 0it [00:00, ?it/s]
# Processing pages: 100%|█████████████████████████| 11/11 [00:03<00:00,  3.09it/s]
# OCR-rec Predict: 100%|██████████████████████████| 23/23 [00:02<00:00,  9.51it/s]
# 2025-05-28 17:12:54.398 | INFO     | magic_pdf.tools.common:_do_parse:243 - local output dir is /Users/lukasfiller/mineru/Decoding-Chinas-AI-Powered-Algorithmic-Cognitive-Warfare-Final/auto

# %%
# !magic-pdf --help
# Out:
# Usage: magic-pdf [OPTIONS]
#
# Options:
#   -v, --version                display the version and exit
#   -p, --path PATH              local filepath or directory. support PDF, PPT,
#                                PPTX, DOC, DOCX, PNG, JPG files  [required]
#   -o, --output-dir PATH        output local directory  [required]
#   -m, --method [ocr|txt|auto]  the method for parsing pdf. ocr: using ocr
#                                technique to extract information from pdf. txt:
#                                suitable for the text-based pdf only and
#                                outperform ocr. auto: automatically choose the
#                                best method for parsing pdf from ocr and txt.
#                                without method specified, auto will be used by
#                                default.
#   -l, --lang TEXT              Input the languages in the pdf (if known) to
#                                improve OCR accuracy.  Optional. You should
#                                input "Abbreviation" with language form url: ht
#                                tps://paddlepaddle.github.io/PaddleOCR/latest/e
#                                n/ppocr/blog/multi_languages.html#5-support-
#                                languages-and-abbreviations
#   -d, --debug BOOLEAN          Enables detailed debugging information during
#                                the execution of the CLI commands.
#   -s, --start INTEGER          The starting page for PDF parsing, beginning
#                                from 0.
#   -e, --end INTEGER            The ending page for PDF parsing, beginning from
#                                0.
#   --help                       Show this message and exit.

# %%
#cleaned up from above

import os
import subprocess
from pathlib import Path

def process_pdf(pdf_path, output_dir=None, language="ch", depth=1, model="auto", verbose=True):
    """
    Process a PDF file through magic-pdf with the specified parameters.
    
    Parameters:
    - pdf_path: Path to the PDF file
    - output_dir: Directory to save output (defaults to ~/mineru/ if None)
    - language: Language code (default: 'ch' for Chinese & English)
    - depth: Processing depth (default: 1)
    - model: Model to use (default: 'auto')
    """
    # Normalize paths
    pdf_path = os.path.expanduser(pdf_path)
    
    if output_dir is None:
        output_dir = os.path.expanduser("~/mineru/")
    else:
        output_dir = os.path.expanduser(output_dir)
    
    # Ensure output directory exists
    Path(output_dir).mkdir(parents=True, exist_ok=True)
    
    # Build and execute the command
    cmd = f'magic-pdf -p "{pdf_path}" -o "{output_dir}" -m {model} -l {language} -d {depth}'

    print(f"Executing: {cmd}")
    
    return subprocess.run(cmd, shell=True)

# Example usage:
# Process a single PDF
process_pdf("/Users/lukasfiller/Downloads/Xinhua_CCP_Brainwashing_Methods_Mar2025_ZH.pdf")

# Process multiple PDFs
#pdfs_to_process = [
#    "~/path/to/first/document.pdf",
#    "~/path/to/second/document.pdf"
#]

#for pdf in pdfs_to_process:
#    process_pdf(pdf)
# Out:
# Executing: magic-pdf -p "/Users/lukasfiller/Downloads/Xinhua_CCP_Brainwashing_Methods_Mar2025_ZH.pdf" -o "/Users/lukasfiller/mineru/" -m auto -l ch -d 1
# 2025-05-14 08:26:13.726 | WARNING  | magic_pdf.libs.config_reader:get_latex_delimiter_config:132 - 'latex-delimiter-config' not found in magic-pdf.json, use 'None' as default
# 2025-05-14 08:26:16.270 | WARNING  | magic_pdf.tools.common:_do_parse:97 - debug mode is on
# 2025-05-14 08:26:16.272 | INFO     | magic_pdf.data.dataset:__init__:157 - lang: ch
# 2025-05-14 08:26:16.372 | INFO     | magic_pdf.libs.pdf_check:detect_invalid_chars:67 - cid_count: 0, text_len: 656, cid_chars_radio: 0.0
# 2025-05-14 08:26:16.400 | INFO     | magic_pdf.model.doc_analyze_by_custom_model:doc_analyze:162 - Batch 1/1: 1 pages/1 pages
# 2025-05-14 08:26:16.403 | INFO     | magic_pdf.model.pdf_extract_kit:__init__:68 - DocAnalysis init, this may take some times, layout_model: doclayout_yolo, apply_formula: True, apply_ocr: True, apply_table: True, table_model: rapid_table, lang: None
# 2025-05-14 08:26:16.403 | INFO     | magic_pdf.model.pdf_extract_kit:__init__:82 - using device: mps
# 2025-05-14 08:26:16.403 | INFO     | magic_pdf.model.pdf_extract_kit:__init__:86 - using models_dir: /Users/lukasfiller/.cache/huggingface/hub/models--opendatalab--PDF-Extract-Kit-1.0/snapshots/14efd64068741c8e1d79d635dd236a80a9db66ba/models
# 2025-05-14 08:26:20.084 | INFO     | magic_pdf.model.pdf_extract_kit:__init__:164 - DocAnalysis init done!
# 2025-05-14 08:26:20.084 | INFO     | magic_pdf.model.doc_analyze_by_custom_model:custom_model_init:116 - model init cost: 3.6821658611297607
# Layout Predict: 100%|██████████| 1/1 [00:01<00:00,  1.09s/it]
# MFD Predict: 100%|██████████| 1/1 [00:00<00:00,  1.13it/s]
# MFR Predict: 0it [00:00, ?it/s]
# OCR-det Predict: 100%|██████████| 1/1 [00:05<00:00,  5.01s/it]
# Table Predict: 0it [00:00, ?it/s]
# Processing pages: 100%|██████████| 1/1 [00:00<00:00,  1.58it/s]
# OCR-rec Predict: 100%|██████████| 1/1 [00:00<00:00,  3.19it/s]
# 2025-05-14 08:26:28.346 | INFO     | magic_pdf.tools.common:_do_parse:243 - local output dir is /Users/lukasfiller/mineru/Xinhua_CCP_Brainwashing_Methods_Mar2025_ZH/auto
# CompletedProcess(args='magic-pdf -p "/Users/lukasfiller/Downloads/Xinhua_CCP_Brainwashing_Methods_Mar2025_ZH.pdf" -o "/Users/lukasfiller/mineru/" -m auto -l ch -d 1', returncode=0)

# %%
# !magic-pdf -p """https://www.secrss.com/articles/78074""" -o ""/content/"" -m auto -l en -d 1

# %%
#magic-pdf -p /path/to/your/pdf_file.pdf -o /path/to/output_directory -m auto
# !magic-pdf --path "https://www.secrss.com/articles/78074" -o output/ -m ocr -d 1
# Out:
# Usage: magic-pdf [OPTIONS]
# Try 'magic-pdf --help' for help.
#
# Error: Invalid value for '-p' / '--path': Path 'https://www.secrss.com/articles/78074' does not exist.

# %%
# !magic-pdf -p "/Users/lukasfiller/Downloads/NBR-China_Vision_New_Order_Jan2020.pdf" -o "/Users/lukasfiller/Downloads/" -m ocr -d 1

# %% [markdown]
# Use GPU

# %%
# !python -m pip install paddlepaddle-gpu==3.0.0b1 -i https://www.paddlepaddle.org.cn/packages/stable/cu118/
#then go into magic-pdf.json and chance device mode to "cuda"

# %% [markdown]
# scrape HTML

# %%
print(data["html"])  # Outputs the main content in HTML format.
# Out:
# <div id="img-content" class="rich_media_wrp">
#
#           <h1 class="rich_media_title " id="activity-name">从认知到行动： 基于互联网的开源情报开发与利用</h1>
#           <div class="rich_media_content js_underline_content
#                        " id="js_content" style="visibility: hidden; opacity: 0; "><p style="line-height: 150%;text-indent: 0em;text-align: center;"><span style="font-size:16px;line-height:150%;font-family:宋体;">李健</span></p><p style="line-height: 150%;text-indent: 0em;text-align: center;margin-bottom: 20px;"><span style="font-size:16px;line-height:150%;font-family:宋体;">知远战略与防务研究所</span></p><p style="text-align: center;"><img class="" data-copyright="0" data-ratio="0.5609375" data-s="300,640" data-src="https://mmbiz.qpic.cn/mmbiz_jpg/5puaLG5r4aauLSDJVW6zTbXM6BZHHRfrpMy0WIgQHmchkKsukibWwK4xrBNaIumDMdxJyMIicibknktIu1gFnxNgw/640?wx_fmt=jpeg" data-type="jpeg" data-w="1280" style="" src="https://mmbiz.qpic.cn/mmbiz_jpg/5puaLG5r4aauLSDJVW6zTbXM6BZHHRfrpMy0WIgQHmchkKsukibWwK4xrBNaIumDMdxJyMIicibknktIu1gFnxNgw/640?wx_fmt=jpeg"></p><p style="text-align: center;"><img class="" data-copyright="0" data-ratio="0.56328125" data-s="300,640" data-src="https://mmbiz.qpic.cn/mmbiz_jpg/5puaLG5r4aauLSDJVW6zTbXM6BZHHRfr1f2kpOX59VTR6cuHQra3q9Roib2eTha3oPHlLYxQdCufj3M0BolwqOg/640?wx_fmt=jpeg" data-type="jpeg" data-w="1280" style="" src="https://mmbiz.qpic.cn/mmbiz_jpg/5puaLG5r4aauLSDJVW6zTbXM6BZHHRfr1f2kpOX59VTR6cuHQra3q9Roib2eTha3oPHlLYxQdCufj3M0BolwqOg/640?wx_fmt=jpeg"></p><p style="text-align: center;"><img class="" data-copyright="0" data-ratio="0.559375" data-s="300,640" data-src="https://mmbiz.qpic.cn/mmbiz_jpg/5puaLG5r4aauLSDJVW6zTbXM6BZHHRfrY5GFWicRuXqMGOXcTgkS7VNw3mhpL06vUQl0XcMs4UhkFeyiaQFicHhXg/640?wx_fmt=jpeg" data-type="jpeg" data-w="1280" style="" src="https://mmbiz.qpic.cn/mmbiz_jpg/5puaLG5r4aauLSDJVW6zTbXM6BZHHRfrY5GFWicRuXqMGOXcTgkS7VNw3mhpL06vUQl0XcMs4UhkFeyiaQFicHhXg/640?wx_fmt=jpeg"></p><p style="text-align: center;"><img class="" data-copyright="0" data-ratio="0.5625" data-s="300,640" data-src="https://mmbiz.qpic.cn/mmbiz_jpg/5puaLG5r4aauLSDJVW6zTbXM6BZHHRfrOl8StdSv3ARpFRIHcVZgHx8a9iax6F8v6187qALMI6gqkK1Xia6OSqZA/640?wx_fmt=jpeg" data-type="jpeg" data-w="1280" style="" src="https://mmbiz.qpic.cn/mmbiz_jpg/5puaLG5r4aauLSDJVW6zTbXM6BZHHRfrOl8StdSv3ARpFRIHcVZgHx8a9iax6F8v6187qALMI6gqkK1Xia6OSqZA/640?wx_fmt=jpeg"></p><p style="text-align: center;"><img class="" data-copyright="0" data-ratio="0.5625" data-s="300,640" data-src="https://mmbiz.qpic.cn/mmbiz_jpg/5puaLG5r4aauLSDJVW6zTbXM6BZHHRfrW5pc3rUZw3sdSqpbwP8oicDXXX5Ynp1uBCj9U5fxdgQ3UjNF2iccbhuA/640?wx_fmt=jpeg" data-type="jpeg" data-w="1280" style="" src="https://mmbiz.qpic.cn/mmbiz_jpg/5puaLG5r4aauLSDJVW6zTbXM6BZHHRfrW5pc3rUZw3sdSqpbwP8oicDXXX5Ynp1uBCj9U5fxdgQ3UjNF2iccbhuA/640?wx_fmt=jpeg"></p><p style="text-align: center;"><img class="" data-copyright="0" data-ratio="0.56328125" data-s="300,640" data-src="https://mmbiz.qpic.cn/mmbiz_jpg/5puaLG5r4aauLSDJVW6zTbXM6BZHHRfrEkVoTn7ZGyzwZgkST7hZXUpZOLmklVlp6s8QNTMQgr0pDF0OKrBkUg/640?wx_fmt=jpeg" data-type="jpeg" data-w="1280" style="" src="https://mmbiz.qpic.cn/mmbiz_jpg/5puaLG5r4aauLSDJVW6zTbXM6BZHHRfrEkVoTn7ZGyzwZgkST7hZXUpZOLmklVlp6s8QNTMQgr0pDF0OKrBkUg/640?wx_fmt=jpeg"></p><p style="text-align: center;"><img class="" data-copyright="0" data-ratio="0.56171875" data-s="300,640" data-src="https://mmbiz.qpic.cn/mmbiz_jpg/5puaLG5r4aauLSDJVW6zTbXM6BZHHRfriaXLibz77ZyccBvHEPejsF27BgvHATvXAwGPjO0lMn9UXqrRkTNQv5VA/640?wx_fmt=jpeg" data-type="jpeg" data-w="1280" style="" src="https://mmbiz.qpic.cn/mmbiz_jpg/5puaLG5r4aauLSDJVW6zTbXM6BZHHRfriaXLibz77ZyccBvHEPejsF27BgvHATvXAwGPjO0lMn9UXqrRkTNQv5VA/640?wx_fmt=jpeg"></p><p style="text-align: center;"><img class="" data-copyright="0" data-ratio="0.5625" data-s="300,640" data-src="https://mmbiz.qpic.cn/mmbiz_jpg/5puaLG5r4aauLSDJVW6zTbXM6BZHHRfrKI9mic1fv5cLdia6fMjF5nqah4hA7G8tj1yS9QwBtJWkp6LG2D49K0icg/640?wx_fmt=jpeg" data-type="jpeg" data-w="1280" style="" src="https://mmbiz.qpic.cn/mmbiz_jpg/5puaLG5r4aauLSDJVW6zTbXM6BZHHRfrKI9mic1fv5cLdia6fMjF5nqah4hA7G8tj1yS9QwBtJWkp6LG2D49K0icg/640?wx_fmt=jpeg"></p><p style="text-align: center;"><img class="" data-copyright="0" data-ratio="0.5609375" data-s="300,640" ...
#
#           </div>

# %%
print(html[:500])  # Print the first 500 characters to verify the HTML content

# %%
from markdownify import markdownify as md

# Function to convert HTML content to Markdown and save
def html_to_markdown(data, output_file="content.md"):
    # Extract the HTML content
    html_content = data.get("html", "")
    title = data.get("title", "Untitled")
    base_url = data.get("base_url", "Unknown Source")
    
    # Convert HTML to Markdown
    markdown_content = md(html_content)
    
    # Combine title, source, and content into Markdown format
    markdown = f"# {title}\n\n"
    markdown += f"**Source:** [Original Article]({base_url})\n\n"
    markdown += markdown_content
    
    # Write to a Markdown file
    with open(output_file, "w", encoding="utf-8") as file:
        file.write(markdown)
    print(f"Markdown content saved to {output_file}")

# Example extracted data from magic-html
data = {
    "title": "From Cognition to Action: Open Source Intelligence Development",
    "html": "<p>This is an example article discussing open source intelligence...</p>",
    "base_url": "https://example.com"
}

# Convert HTML to Markdown and save
html_to_markdown(data)
# Out:
# Markdown content saved to content.md

# %%
# !magic-pdf -h

# %% [markdown]
# ##Convert HTML to Markdown (works)
