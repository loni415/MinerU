# %%
# !mineru-models-download --help
# Out:
# Usage: mineru-models-download [OPTIONS]
#
#   Download MinerU model files.
#
#   Supports downloading pipeline or VLM models from ModelScope or HuggingFace.
#
# Options:
#   -s, --source [huggingface|modelscope]
#                                   The source of the model repository.
#   -m, --model_type [pipeline|vlm|all]
#                                   The type of the model to download.
#   --help                          Show this message and exit.

# %%
# !mineru-models-download --source huggingface --model_type pipeline
# Out:
# 2025-10-27 22:04:12.304 | INFO     | mineru.cli.models_download:download_models:135 - Downloading pipeline model from huggingface...
# 2025-10-27 22:04:12.304 | INFO     | mineru.cli.models_download:download_pipeline_models:77 - Downloading model: models/Layout/YOLO/doclayout_yolo_docstructbench_imgsz1280_2501.pt
# Fetching 1 files: 100%|████████████████████████| 1/1 [00:00<00:00, 17848.10it/s]
# 2025-10-27 22:04:12.758 | INFO     | mineru.cli.models_download:download_pipeline_models:77 - Downloading model: models/MFD/YOLO/yolo_v8_ft.pt
# Fetching 1 files: 100%|█████████████████████████| 1/1 [00:00<00:00, 1609.48it/s]
# 2025-10-27 22:04:12.915 | INFO     | mineru.cli.models_download:download_pipeline_models:77 - Downloading model: models/MFR/unimernet_hf_small_2503
# Fetching 7 files: 100%|████████████████████████| 7/7 [00:00<00:00, 44150.57it/s]
# ...

# %% [markdown]
# models are at:"/home/mebuntu/.cache/huggingface/hub/models--opendatalab--PDF-Extract-Kit-1.0/snapshots/1d9a3cd772329d0f83d84638a789296863f940f9"
#
# mineru.json config file at: /home/mebuntu/mineru.json

# %%
mineru -p <input_path> -o <output_path> --source local --backend pipeline --language ch_server
