# %%
# !pip install --upgrade pip
# !pip install "mineru[core]>=2.0.0"

# %%
# !mineru-models-download

# %%
# !mineru -p /content/china_galaxy_mil_industry_report_2018_zh.pdf -o /content/output --source local

# %% [markdown]
# Yes, after executing the command mineru-models-download in the console window to download the model, the mineru.json file will be automatically created in the C:\Users\username folder. If you want to download it all at once, if the network is unstable, there may be no mineru.json.
#
# }, " llm-aided-config ":
# {
# "title_aided": {
# "api_key
# " :
# "your_api_key",
# "base_url": " https://dashscope.aliyuncs.com/compatible-mode/v1 "
# ,
# "model ": "qwen2.5-32b-instruct" , "enable": false } }, "models-dir": { " pipeline": "https://dashscope.aliyuncs.com/compatible-mode/v1 " , "data": "https://dashscope.aliyuncs.com/compatible-mode/v1 " , "data": "https://dashscope.aliyuncs.com/compatible-mode/v1 " , "data" : "https://dashscope.aliyuncs.com/compatible-mode/v1 ", " data": " https://dashscope.aliyuncs.com/compatible-mode/v1 ", "data": "https://dashscope.aliyuncs.com/compatible-mode/v1 ", " data" : "https://dashscope.aliyuncs.com/compatible-mode/v1 " , " data ": " "C:\Users\username\.cache\modelscope\hub\models\OpenDataLab\PDF-Extract-Kit-1___0", "vlm": "C:\Users\username\.cache\modelscope\hub\models\OpenDataLab\MinerU2___0-2505-0___9B" }, "config_version": "1.3.0" }
